# %%
#imports
import os
import sys
from pathlib import Path
import pickle

# %%
# !pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from GetOldTweets3) (4.2.6)
# Collecting pyquery>=1.2.10
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

import re
import nltk
nltk.download('stopwords')
from time import time
# !pip install emoji
from emoji import demojize

#Preprocessing functions. Again the preprocessing functions in old_dataset_data_and_models can also be used
def preprocess(texts, quiet=False):
  start = time()
  # Lowercasing
  texts = texts.str.lower()

  # Remove special chars
  texts = texts.str.replace(r"(http|@)\S+", "")
  texts = texts.apply(demojize)
  texts = texts.str.replace(r"::", ": :")
  texts = texts.str.replace(r"’", "'")
  texts = texts.str.replace(r"[^a-z\':_]", " ")

  # Remove repetitions
  pattern = re.compile(r"(.)\1{2,}", re.DOTALL)
  texts = texts.str.replace(pattern, r"\1")

  # Transform short negation form
  texts = texts.str.replace(r"(can't|cannot)", 'can not')
  texts = texts.str.replace(r"n't", ' not')

  # Remove stop words
  stopwords = nltk.corpus.stopwords.words('english')
  stopwords.remove('not')
  stopwords.remove('nor')
  stopwords.remove('no')
  texts = texts.apply(
    lambda x: ' '.join([word for word in x.split() if word not in stopwords])
  )

  if not quiet:
    print("Time to clean up: {:.2f} sec".format(time() - start))

  return texts
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/40/8d/521be7f0091fe0f2ae690cc044faf43e3445e0ff33c574eae752dd7e39fa/emoji-0.5.4.tar.gz (43kB)
#      |████████████████████████████████| 51kB 1.7MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.5.4-cp36-none-any.whl size=42176 sha256=e33ca33a86c00aa09fae3e78169eebcaeb177a8bbb9bb76fc9686d1286f76e12
#   Stored in directory: /root/.cache/pip/wheels/2a/a9/0a/4f8e8cce8074232aba240caca3fade315bb49fac68808d1a9c
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.5.4

# %%
import GetOldTweets3 as got
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Input, Embedding, SpatialDropout1D, LSTM
from tensorflow.keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Bidirectional, Conv1D, Dense, concatenate
from tensorflow.keras.models import Model

#function for prediction of emotion of tweets of specific student
def predict_emotion_for_student(username,date,write="true"):
  tweetCriteria = got.manager.TweetCriteria().setUsername(username).setSince(date).setEmoji("unicode")
  tweets = got.manager.TweetManager.getTweets(tweetCriteria)

  if len(tweets)>0:

    data = []
    for tweet in tweets:
        data.append([tweet.id, tweet.username, tweet.text])
    df = pd.DataFrame(data=data, columns=['id', 'user', 'text'])
    #print(str(len(data)) + ' tweets')

    tokenizer_path = Path('tokenizer.pickle').resolve()
    with tokenizer_path.open('rb') as file:
      tokenizer = pickle.load(file)
    
    input_dim = min(tokenizer.num_words, len(tokenizer.word_index) + 1)
    num_classes = 4
    embedding_dim = 100
    input_length = 142
    lstm_units = 128
    lstm_dropout = 0.1
    recurrent_dropout = 0.1
    spatial_dropout=0.2
    filters=64
    kernel_size=4
    #print(input_dim)
    #print(len(tokenizer.word_index))

    input_layer = Input(shape=(input_length,))
    output_layer = Embedding(
    input_dim=input_dim,
    output_dim=50,
    input_shape=(input_length,)
    )(input_layer)

    output_layer = SpatialDropout1D(spatial_dropout)(output_layer)

    output_layer = Bidirectional(
    LSTM(128, return_sequences=True,
        dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)
    )(output_layer)
    output_layer = Conv1D(filters, kernel_size=kernel_size, padding='valid',
                        kernel_initializer='glorot_uniform')(output_layer)

    avg_pool = GlobalAveragePooling1D()(output_layer)
    max_pool = GlobalMaxPooling1D()(output_layer)
    output_layer = concatenate([avg_pool, max_pool])

    output_layer = Dense(num_classes, activation='softmax')(output_layer)

    model = Model(input_layer, output_layer)
    model_weights_path = Path('model_weights88.h5').resolve()
    model.load_weights(model_weights_path.as_posix())

    encoder_path = Path('encoder.pickle').resolve()
    with encoder_path.open('rb') as file:
      encoder = pickle.load(file)

    cleaned_data = preprocess(df.text)
    sequences = [text.split() for text in cleaned_data]
    list_tokenized = tokenizer.texts_to_sequences(sequences)
    x_data = pad_sequences(list_tokenized, maxlen=100)

    y_pred = model.predict(x_data)

    #print(df.text)
    print(encoder.inverse_transform(y_pred[0:]))
    predictions = encoder.inverse_transform(y_pred[0:])

    rs_df = pd.DataFrame({"text":df.text, "label":predictions})
    if write:
      print(rs_df)
    return predictions
  
  lis = []
  return lis

# %%
pr = predict_emotion_for_student("mansi_sampat","2020-05-18")
# Out:
# Time to clean up: 0.18 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_1:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'anger' 'fear' 'anger' 'fear' 'joy']
#                                                 text  label
# 0  This is the same story everywhere. We SVNIT st...    joy
# 1               #twinglish #grammarhelp #writebetter    joy
# 2  Another attempt to improve some vocal skills🤞😅...    joy
# 3  I have been working on improving my verbal ski...    joy
# 4  The is irksome to witness the proclivity of th...  anger
# 5  Since our insti is so adamant about conducting...   fear
# 6  Additionally, our syllabus which would've take...  anger
# 7  Sir, I agree to the fact that students build u...   fear
# 8  We demand considering our point of view before...    joy

# %%
#Fetching of SVNIT student twitter handles
emotions = []
users = []
file = open('twitter_handles', 'r')
for line in file:
  users.append(line[:len(line)-1])

for user in users:
  print(user)
  em = predict_emotion_for_student(user,"2020-05-20",False)
  emotions.extend(em)
# Out:
# Maulikchevli
# AdityaHirapara
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_80:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# KShah2207
# therohitramesh
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_81:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'joy' 'joy' 'joy' 'joy' 'sadness' 'sadness' 'joy' 'fear' 'joy'
#  'anger']
# DhavalR33750364
# yashdabhade19
# Aaditya27662146
# ThampiAtheesh
# shameel_zeshan
# 18raj98
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_82:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['sadness' 'joy' 'joy' 'joy' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'fear' 'joy' 'joy' 'joy' 'joy' 'joy' 'anger' 'joy']
# MitanshuThakore
# vaibhavgeek
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_83:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'anger' 'anger' 'joy' 'fear' 'joy' 'joy' 'joy']
# AniketSur4
# saneJokerrr
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_84:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'joy' 'anger' 'anger' 'anger' 'fear']
# Sourab98
# ShyamSB21598
# vin_sonkar
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_85:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy']
# Yashpatels2
# neetashpataria
# yash109916
# Rogink13
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_86:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear']
# anasabbas
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_87:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'fear' 'joy' 'joy' 'fear']
# ajayns_
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_88:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'joy' 'fear' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'joy' 'joy' 'joy' 'joy' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy']
# vasukoradiya
# ShridevC
# Rahul_Lad98
# RiddhiMore2
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_89:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy']
# nikimore2698
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_90:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'joy' 'fear' 'fear' 'joy' 'anger' 'joy' 'joy'
#  'joy' 'anger']
# JainKeval108
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_91:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# whoshreyaspatel
# Rushi_Bhatt007
# choupare
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_92:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# kevinjameskay
# vivekagal1998
# therohitramesh
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_93:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'joy' 'joy' 'joy' 'joy' 'sadness' 'sadness' 'joy' 'fear' 'joy'
#  'anger']
# mirdotbhatia
# Hrishab46986230
# RanderiaApurva
# PManikantasai
# VarshneySourabh
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_94:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'fear' 'anger' 'anger' 'joy' 'joy' 'joy' 'fear' 'anger']
# ViramShah4
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_95:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# Jaimin96570565
# darsh2198
# shimpi_tanmay
# rationalrajat04
# Atha_Kalsekar
# AmbedkarSanket
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_96:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger']
# nikimore2698
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_97:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'joy' 'fear' 'fear' 'joy' 'anger' 'joy' 'joy'
#  'joy' 'anger']
# mrfshk
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_98:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear']
# akshay_busa
# SportyNoel
# n_talaviya
# rrathi1999
# RohitashvSharma
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_99:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['sadness' 'joy' 'joy' 'fear' 'joy' 'joy']
# vashwini409
# GAURAVN11469510
# gauravk1278
# parthav46
# VISHAL91064
# PKhevna
# _PratikSuthar
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_100:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger' 'fear' 'fear']
# SamarthJModi
# abhijeetmathur7
# vidhey_1
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_101:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy']
# shivam_makwana
# being_nerdy_
# VRSonawane13
# sz20J
# Siddharth060998
# Kishan248
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_102:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'joy']
# satram_9
# puneetkukreja11
# ankulalbert
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_103:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger' 'joy']
# Kailash75309353
# LalitGoyal9320
# RANJEET07094620
# jalu_jaydeep
# RavatMal
# Keshav__3
# Time to clean up: 0.02 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_104:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'fear' 'joy' 'joy' 'anger' 'joy' 'sadness' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'sadness' 'fear' 'anger' 'joy' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy'
#  'sadness' 'joy' 'joy' 'fear' 'fear' 'joy' 'joy' 'fear' 'anger' 'fear'
#  'anger' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'sadness' 'joy' 'joy' 'joy'
#  'joy' 'anger' 'sadness' 'joy' 'joy' 'anger' 'joy' 'joy' 'anger' 'joy'
#  'sadness' 'joy' 'joy' 'joy' 'fear']
# lokeshnagar855
# Rinkesh11944920
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_105:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'anger']
# YashSutariya_02
# HardikBabriya11
# akhilammu1
# _chint4n_
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_106:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear']
# TheeAbhinavJain
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_107:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger' 'joy']
# kulkarni_sayee
# pranjal_soni_
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_108:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy']
# vedanshagarwal4
# vaibhavgeek
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_109:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'anger' 'anger' 'joy' 'fear' 'joy' 'joy' 'joy']
# RajatSvN
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_110:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# imabhay_dubey
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_111:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'anger' 'joy' 'joy' 'joy' 'joy' 'anger' 'fear' 'joy' 'fear' 'anger'
#  'joy' 'anger' 'joy']
# mpsmahima
# _Mikku_1205_
# bunty_1708
# Brijptl1212
# ModiMohik
# meet_kachhadia
# DarshilTailor
# BhumitSagathiya
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_112:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger' 'anger']
# jainildesai007
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_113:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'joy' 'anger' 'joy']
# Jainish20714735
# RajKabrawala
# rvn2025
# darshak008
# rimalparikh
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_114:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear']
# impratik1998
# AbhasBhatia
# aanchal_handa
# vgpatel1997
# ruchitpatel007
# umangchavda96
# MasterVaishnovy
# KartikSabal
# sameermandloi1
# ronik_gandhi
# AkashAppari
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_115:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy' 'joy']
# Asitabh29
# ShraddhaAg
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_116:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'fear' 'joy' 'joy' 'joy' 'joy' 'fear' 'fear' 'joy' 'joy' 'fear'
#  'joy' 'joy' 'joy']
# ButtiDhruvi
# n15argMakwana
# ParmarMeet18
# AakankshaD_
# RishiMi24
# AjayRajpurohit1
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_117:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# ps01sharma
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_118:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['sadness' 'joy']
# raghav_sensei
# Mrityun59643942
# rajeshmeena9898
# Yash_Kavaiya_
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_119:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'fear']
# Monu_aesthetic
# soumitjana
# shubhampatel101
# SRthummar0
# NarvesinghB
# iamprajapati99
# harish34743
# SahilUnagar
# jaykotadiya1261
# mukesh_kumar184
# NiluBhai42
# NiyatiVyas22
# Irfan24k
# raghav_sensei
# Vaibhavkhobrag9
# AdityaA60797705
# atul_satul
# Bikku47
# akashra58993704
# shreaya03
# TarangDesai7
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_120:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'anger' 'joy' 'sadness' 'joy' 'joy' 'joy' 'fear' 'joy' 'anger'
#  'sadness' 'fear' 'joy' 'fear' 'joy' 'anger' 'fear' 'joy' 'anger' 'anger'
#  'anger' 'joy' 'joy' 'fear']
# innov_abhay
# arth_sha
# arpan_0699
# AmanVishera
# ArmanMa61633878
# Dhvanil65059087
# adityajaiswal84
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_121:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['anger' 'joy' 'sadness' 'joy' 'joy' 'sadness' 'joy' 'joy' 'fear' 'joy'
#  'joy' 'joy' 'joy']
# kishnrathod
# saigoodbetter
# RahulKu83156038
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_122:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# jonty_ujjawal
# AmanGondaliya4
# AmnPandey
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_123:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'anger']
# Urvil1804
# AjayRachuri
# ananyo0101
# Rajdeep_99
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_124:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy']
# rramkumar1997
# SwastikBSB
# Aniketvs08
# rahultnene
# vatsal_28
# SuyashS42652857
# Rishabh14963754
# insi_yah
# SuriKshitij
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_125:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'joy' 'anger' 'joy' 'joy' 'joy' 'joy' 'joy' 'anger']
# TheEshanArora
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_126:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy' 'fear' 'sadness' 'anger' 'fear' 'joy' 'joy' 'joy' 'joy'
#  'fear' 'joy' 'joy' 'anger' 'joy' 'joy' 'anger' 'fear' 'anger' 'anger'
#  'joy' 'anger']
# dbhatt25
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_127:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# dhvanilvadher20
# shravan9892
# SoniSanjeev007
# Its_saptarishi
# NisargS89746052
# Aniirso
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_128:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear' 'fear' 'anger']
# vivek_hc
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_129:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy']
# me_jignesh
# the_abhisar
# UdaiPratap_Rao
# mitalidesai17
# bhaveshgohil
# DiptiRana5
# RakeshG74488365
# Ronak8585
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_130:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['fear']
# vipulbhavsar
# Vishnud38140901
# HarnishRajput
# Time to clean up: 0.01 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_131:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'fear' 'fear' 'joy' 'joy' 'joy' 'joy' 'joy']
# NikunjS88887207
# AnilCha14524312
# Shivani91981451
# ShahRaj50375899
# hellodivyani
# Time to clean up: 0.00 sec
# WARNING:tensorflow:Model was constructed with shape (None, 142) for input Tensor("input_132:0", shape=(None, 142), dtype=float32), but it was called on an input with incompatible shape (None, 100).
# ['joy' 'joy']
# MagguMudita
# Pennywise97
# apurva_tr

# %%
number_joy = 0
number_sadness = 0
number_anger = 0
number_fear = 0
for emotion in emotions:
  if emotion == "joy":
    number_joy = number_joy + 1
  elif emotion == "sadness":
    number_sadness = number_sadness + 1
  elif emotion == "anger":
    number_anger = number_anger + 1
  elif emotion == "fear":
    number_fear = number_fear + 1

# %%
#Percentage of emotions of SVNIT students
print("Anger = " + str(number_anger/len(emotions)))
print("Fear = " + str(number_fear/len(emotions)))
print("Joy = " + str(number_joy/len(emotions)))
print("Sadness = " + str(number_sadness/len(emotions)))
# Out:
# Anger = 0.1341772151898734
# Fear = 0.15443037974683543
# Joy = 0.6658227848101266
# Sadness = 0.04556962025316456
